# %%
import os
import glob
import numpy as np
import librosa
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping

# %%
def extract_mfcc_sequence(file_path, n_mfcc=40, max_len=200):
    y, sr = librosa.load(file_path, res_type='scipy')
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
    # Pad or truncate to fixed length for batching
    if mfcc.shape[1] < max_len:
        pad_width = max_len - mfcc.shape[1]
        mfcc = np.pad(mfcc, pad_width=((0,0),(0,pad_width)), mode='constant')
    else:
        mfcc = mfcc[:, :max_len]
    return mfcc.T  # Shape: (max_len, n_mfcc)

# %%
emotions = {
    '01': 'neutral', '02': 'calm', '03': 'happy', '04': 'sad',
    '05': 'angry', '06': 'fearful', '07': 'disgust', '08': 'surprised'
}
observed_emotions = list(emotions.values())

def load_data_dl(test_size=0.2, max_len=200):
    x, y = [], []
    # Update these paths for your dataset
    speech_files = glob.glob('/Users/dushyantyadav/Downloads/Audio_Speech_Actors_01-24/Actor*/**/*.wav', recursive=True)
    song_files = glob.glob('/Users/dushyantyadav/Downloads/Audio_Song_Actors_01-24/Actor*/**/*.wav', recursive=True)
    all_files = speech_files + song_files
    for file in all_files:
        file_name = os.path.basename(file)
        emotion_code = file_name.split("-")[2]
        emotion = emotions.get(emotion_code)
        if emotion not in observed_emotions:
            continue
        try:
            mfcc_seq = extract_mfcc_sequence(file, max_len=max_len)
            x.append(mfcc_seq)
            y.append(emotion)
        except Exception as e:
            print(f"Error processing {file}: {e}")
    x = np.array(x)
    y = np.array(y)
    le = LabelEncoder()
    y_enc = le.fit_transform(y)
    y_cat = to_categorical(y_enc)
    x_train, x_test, y_train, y_test = train_test_split(x, y_cat, test_size=test_size, random_state=42, stratify=y)
    return x_train, x_test, y_train, y_test, le

# %%
def build_cnn_lstm(input_shape, num_classes):
    model = Sequential()
    model.add(Conv1D(64, kernel_size=5, activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(Conv1D(128, kernel_size=5, activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.3))
    model.add(LSTM(128, return_sequences=False))
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(num_classes, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %%
# Load data
x_train, x_test, y_train, y_test, le = load_data_dl(test_size=0.2, max_len=200)
input_shape = x_train.shape[1:]  # (max_len, n_mfcc)
num_classes = y_train.shape[1]

# Build model
model = build_cnn_lstm(input_shape, num_classes)

# Early stopping for better generalization
#early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train
history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=100,
    batch_size=32,
    #callbacks=[early_stop]
)

# Evaluate
loss, acc = model.evaluate(x_test, y_test)
print("Test accuracy:", acc)
from sklearn.metrics import classification_report, confusion_matrix
y_pred = np.argmax(model.predict(x_test), axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred, target_names=le.classes_))
print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
# Out:
# Epoch 1/100
# 62/62 [==============================] - 4s 35ms/step - loss: 1.9835 - accuracy: 0.2177 - val_loss: 2.4694 - val_accuracy: 0.1527
# Epoch 2/100
# 62/62 [==============================] - 1s 24ms/step - loss: 1.7575 - accuracy: 0.2953 - val_loss: 2.1023 - val_accuracy: 0.2138
# Epoch 3/100
# 62/62 [==============================] - 2s 25ms/step - loss: 1.7330 - accuracy: 0.3009 - val_loss: 2.2422 - val_accuracy: 0.1955
# Epoch 4/100
# 62/62 [==============================] - 1s 24ms/step - loss: 1.6243 - accuracy: 0.3447 - val_loss: 1.6511 - val_accuracy: 0.3585
# Epoch 5/100
# 62/62 [==============================] - 1s 24ms/step - loss: 1.5381 - accuracy: 0.3947 - val_loss: 1.5343 - val_accuracy: 0.3809
# Epoch 6/100
# 62/62 [==============================] - 2s 24ms/step - loss: 1.4596 - accuracy: 0.4278 - val_loss: 1.5528 - val_accuracy: 0.3992
# Epoch 7/100
# 62/62 [==============================] - 1s 24ms/step - loss: 1.3859 - accuracy: 0.4600 - val_loss: 1.5994 - val_accuracy: 0.3910
# Epoch 8/100
# 62/62 [==============================] - 1s 23ms/step - loss: 1.3448 - accuracy: 0.4972 - val_loss: 1.3660 - val_accuracy: 0.4623
# Epoch 9/100
# 62/62 [==============================] - 1s 23ms/step - loss: 1.2209 - accuracy: 0.5365 - val_loss: 2.4679 - val_accuracy: 0.3360
# Epoch 10/100
# 62/62 [==============================] - 1s 24ms/step - loss: 1.1265 - accuracy: 0.5783 - val_loss: 1.4789 - val_accuracy: 0.4868
# Epoch 11/100
# 62/62 [==============================] - 1s 24ms/step - loss: 1.0242 - accuracy: 0.6328 - val_loss: 1.1225 - val_accuracy: 0.5927
# Epoch 12/100
# 62/62 [==============================] - 1s 23ms/step - loss: 0.9461 - accuracy: 0.6573 - val_loss: 0.9684 - val_accuracy: 0.6395
# Epoch 13/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.8533 - accuracy: 0.6951 - val_loss: 1.1108 - val_accuracy: 0.6049
# Epoch 14/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.8231 - accuracy: 0.7037 - val_loss: 1.0624 - val_accuracy: 0.5988
# Epoch 15/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.8274 - accuracy: 0.6981 - val_loss: 1.0531 - val_accuracy: 0.6171
# Epoch 16/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.7476 - accuracy: 0.7262 - val_loss: 0.9176 - val_accuracy: 0.6415
# Epoch 17/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.7005 - accuracy: 0.7358 - val_loss: 1.4883 - val_accuracy: 0.5173
# Epoch 18/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.6979 - accuracy: 0.7440 - val_loss: 0.9770 - val_accuracy: 0.6253
# Epoch 19/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.6302 - accuracy: 0.7721 - val_loss: 0.8368 - val_accuracy: 0.6823
# Epoch 20/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.5745 - accuracy: 0.7945 - val_loss: 0.8451 - val_accuracy: 0.6864
# Epoch 21/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.6008 - accuracy: 0.7817 - val_loss: 1.1007 - val_accuracy: 0.6354
# Epoch 22/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.5717 - accuracy: 0.7940 - val_loss: 1.6498 - val_accuracy: 0.5275
# Epoch 23/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.5392 - accuracy: 0.8088 - val_loss: 0.9957 - val_accuracy: 0.6619
# Epoch 24/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.4966 - accuracy: 0.8276 - val_loss: 0.7541 - val_accuracy: 0.7271
# Epoch 25/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.5765 - accuracy: 0.7919 - val_loss: 0.7609 - val_accuracy: 0.7047
# Epoch 26/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.4838 - accuracy: 0.8322 - val_loss: 0.9415 - val_accuracy: 0.6782
# Epoch 27/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.4803 - accuracy: 0.8332 - val_loss: 0.9116 - val_accuracy: 0.6864
# Epoch 28/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.4384 - accuracy: 0.8465 - val_loss: 1.0072 - val_accuracy: 0.6762
# Epoch 29/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3884 - accuracy: 0.8669 - val_loss: 0.8389 - val_accuracy: 0.6945
# Epoch 30/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3704 - accuracy: 0.8644 - val_loss: 0.8115 - val_accuracy: 0.6986
# Epoch 31/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3898 - accuracy: 0.8638 - val_loss: 0.8548 - val_accuracy: 0.7108
# Epoch 32/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3518 - accuracy: 0.8781 - val_loss: 0.9662 - val_accuracy: 0.7026
# Epoch 33/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3777 - accuracy: 0.8705 - val_loss: 0.8371 - val_accuracy: 0.7149
# Epoch 34/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.3776 - accuracy: 0.8644 - val_loss: 0.6987 - val_accuracy: 0.7658
# Epoch 35/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3164 - accuracy: 0.8909 - val_loss: 0.7590 - val_accuracy: 0.7230
# Epoch 36/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3063 - accuracy: 0.8929 - val_loss: 0.7218 - val_accuracy: 0.7454
# Epoch 37/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3000 - accuracy: 0.9031 - val_loss: 0.7637 - val_accuracy: 0.7576
# Epoch 38/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.2788 - accuracy: 0.9062 - val_loss: 0.7053 - val_accuracy: 0.7699
# Epoch 39/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3038 - accuracy: 0.8904 - val_loss: 0.8495 - val_accuracy: 0.7332
# Epoch 40/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.2405 - accuracy: 0.9199 - val_loss: 0.6759 - val_accuracy: 0.7678
# Epoch 41/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2321 - accuracy: 0.9148 - val_loss: 0.9256 - val_accuracy: 0.7149
# Epoch 42/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2270 - accuracy: 0.9240 - val_loss: 0.8493 - val_accuracy: 0.7210
# Epoch 43/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.2281 - accuracy: 0.9199 - val_loss: 0.6714 - val_accuracy: 0.7963
# Epoch 44/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.2238 - accuracy: 0.9230 - val_loss: 0.8810 - val_accuracy: 0.7230
# Epoch 45/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.2409 - accuracy: 0.9123 - val_loss: 0.7871 - val_accuracy: 0.7658
# Epoch 46/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.3184 - accuracy: 0.8909 - val_loss: 0.9060 - val_accuracy: 0.7067
# Epoch 47/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1931 - accuracy: 0.9337 - val_loss: 0.8370 - val_accuracy: 0.7454
# Epoch 48/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.2157 - accuracy: 0.9220 - val_loss: 0.8690 - val_accuracy: 0.7536
# Epoch 49/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.2201 - accuracy: 0.9291 - val_loss: 0.8105 - val_accuracy: 0.7454
# Epoch 50/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1474 - accuracy: 0.9505 - val_loss: 0.7883 - val_accuracy: 0.7515
# Epoch 51/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1689 - accuracy: 0.9454 - val_loss: 0.7154 - val_accuracy: 0.7862
# Epoch 52/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1886 - accuracy: 0.9291 - val_loss: 1.0455 - val_accuracy: 0.7515
# Epoch 53/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.2388 - accuracy: 0.9138 - val_loss: 0.7518 - val_accuracy: 0.7658
# Epoch 54/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1589 - accuracy: 0.9495 - val_loss: 0.6428 - val_accuracy: 0.8126
# Epoch 55/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1457 - accuracy: 0.9485 - val_loss: 0.8114 - val_accuracy: 0.7780
# Epoch 56/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.2516 - accuracy: 0.9169 - val_loss: 0.7209 - val_accuracy: 0.7963
# Epoch 57/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1958 - accuracy: 0.9347 - val_loss: 0.7902 - val_accuracy: 0.7617
# Epoch 58/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1494 - accuracy: 0.9465 - val_loss: 0.7961 - val_accuracy: 0.7637
# Epoch 59/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1325 - accuracy: 0.9536 - val_loss: 0.9119 - val_accuracy: 0.7699
# Epoch 60/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.1609 - accuracy: 0.9444 - val_loss: 0.7743 - val_accuracy: 0.7821
# Epoch 61/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1305 - accuracy: 0.9521 - val_loss: 0.7850 - val_accuracy: 0.7923
# Epoch 62/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1312 - accuracy: 0.9587 - val_loss: 0.8525 - val_accuracy: 0.7617
# Epoch 63/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1167 - accuracy: 0.9618 - val_loss: 0.7337 - val_accuracy: 0.7821
# Epoch 64/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1132 - accuracy: 0.9648 - val_loss: 0.9078 - val_accuracy: 0.7719
# Epoch 65/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1544 - accuracy: 0.9521 - val_loss: 0.7311 - val_accuracy: 0.7943
# Epoch 66/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1709 - accuracy: 0.9408 - val_loss: 0.8113 - val_accuracy: 0.7780
# Epoch 67/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1642 - accuracy: 0.9429 - val_loss: 0.7704 - val_accuracy: 0.8187
# Epoch 68/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1049 - accuracy: 0.9674 - val_loss: 1.5113 - val_accuracy: 0.6578
# Epoch 69/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.1158 - accuracy: 0.9577 - val_loss: 0.8789 - val_accuracy: 0.7862
# Epoch 70/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0885 - accuracy: 0.9714 - val_loss: 0.8651 - val_accuracy: 0.8024
# Epoch 71/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.1181 - accuracy: 0.9648 - val_loss: 0.7581 - val_accuracy: 0.7984
# Epoch 72/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.1518 - accuracy: 0.9495 - val_loss: 0.9317 - val_accuracy: 0.7699
# Epoch 73/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1167 - accuracy: 0.9567 - val_loss: 0.7314 - val_accuracy: 0.7923
# Epoch 74/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0926 - accuracy: 0.9684 - val_loss: 0.7881 - val_accuracy: 0.8126
# Epoch 75/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.1146 - accuracy: 0.9597 - val_loss: 0.7458 - val_accuracy: 0.8004
# Epoch 76/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1198 - accuracy: 0.9567 - val_loss: 0.6632 - val_accuracy: 0.8187
# Epoch 77/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.1019 - accuracy: 0.9704 - val_loss: 0.7380 - val_accuracy: 0.8167
# Epoch 78/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0712 - accuracy: 0.9760 - val_loss: 0.7160 - val_accuracy: 0.8045
# Epoch 79/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1560 - accuracy: 0.9495 - val_loss: 0.8520 - val_accuracy: 0.7800
# Epoch 80/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1841 - accuracy: 0.9444 - val_loss: 0.6855 - val_accuracy: 0.8126
# Epoch 81/100
# 62/62 [==============================] - 2s 28ms/step - loss: 0.1131 - accuracy: 0.9628 - val_loss: 0.7024 - val_accuracy: 0.7780
# Epoch 82/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.0766 - accuracy: 0.9771 - val_loss: 0.7251 - val_accuracy: 0.8024
# Epoch 83/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0553 - accuracy: 0.9827 - val_loss: 0.6348 - val_accuracy: 0.8452
# Epoch 84/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0787 - accuracy: 0.9760 - val_loss: 0.8183 - val_accuracy: 0.8106
# Epoch 85/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0717 - accuracy: 0.9765 - val_loss: 0.7625 - val_accuracy: 0.8167
# Epoch 86/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0747 - accuracy: 0.9755 - val_loss: 0.7529 - val_accuracy: 0.8228
# Epoch 87/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0570 - accuracy: 0.9832 - val_loss: 0.9456 - val_accuracy: 0.7943
# Epoch 88/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.0787 - accuracy: 0.9755 - val_loss: 0.6917 - val_accuracy: 0.8167
# Epoch 89/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.1061 - accuracy: 0.9648 - val_loss: 0.7734 - val_accuracy: 0.7923
# Epoch 90/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0735 - accuracy: 0.9776 - val_loss: 0.6097 - val_accuracy: 0.8371
# Epoch 91/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0737 - accuracy: 0.9740 - val_loss: 0.7891 - val_accuracy: 0.8187
# Epoch 92/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.0763 - accuracy: 0.9755 - val_loss: 0.8150 - val_accuracy: 0.8126
# Epoch 93/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0923 - accuracy: 0.9663 - val_loss: 0.6799 - val_accuracy: 0.8371
# Epoch 94/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0784 - accuracy: 0.9806 - val_loss: 0.6765 - val_accuracy: 0.8330
# Epoch 95/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0481 - accuracy: 0.9862 - val_loss: 0.7526 - val_accuracy: 0.8208
# Epoch 96/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0703 - accuracy: 0.9786 - val_loss: 0.7660 - val_accuracy: 0.8269
# Epoch 97/100
# 62/62 [==============================] - 2s 25ms/step - loss: 0.0461 - accuracy: 0.9842 - val_loss: 0.7470 - val_accuracy: 0.8167
# Epoch 98/100
# 62/62 [==============================] - 2s 24ms/step - loss: 0.0363 - accuracy: 0.9878 - val_loss: 0.9416 - val_accuracy: 0.7923
# Epoch 99/100
# 62/62 [==============================] - 1s 24ms/step - loss: 0.0698 - accuracy: 0.9791 - val_loss: 0.9264 - val_accuracy: 0.7984
# Epoch 100/100
# 62/62 [==============================] - 1s 23ms/step - loss: 0.0488 - accuracy: 0.9827 - val_loss: 0.8939 - val_accuracy: 0.8065
# 16/16 [==============================] - 0s 12ms/step - loss: 0.8939 - accuracy: 0.8065
# Test accuracy: 0.8065173029899597
# 16/16 [==============================] - 0s 8ms/step
#               precision    recall  f1-score   support
#
#        angry       0.92      0.88      0.90        75
#         calm       0.94      0.85      0.90        75
#      disgust       0.93      0.64      0.76        39
#      fearful       0.78      0.65      0.71        75
#        happy       0.78      0.87      0.82        75
#      neutral       0.69      0.92      0.79        38
#          sad       0.74      0.80      0.77        75
#    surprised       0.70      0.82      0.75        39
#
#     accuracy                           0.81       491
#    macro avg       0.81      0.80      0.80       491
# weighted avg       0.82      0.81      0.81       491
#
# Confusion Matrix:
#  [[66  0  2  2  3  0  2  0]
#  [ 0 64  0  0  2  7  2  0]
#  [ 5  0 25  4  0  2  1  2]
#  [ 1  0  0 49  6  0 14  5]
#  [ 0  2  0  0 65  3  0  5]
#  [ 0  0  0  0  0 35  2  1]
#  [ 0  2  0  7  2  3 60  1]
#  [ 0  0  0  1  5  1  0 32]]

# %%
# Example for a deep learning pipeline using MFCCs
test_file = '/Users/dushyantyadav/Downloads/Crema/1001_DFA_ANG_XX.wav'
mfcc_seq = extract_mfcc_sequence(test_file, max_len=200)  # Use your pipeline's function
mfcc_seq = np.expand_dims(mfcc_seq, axis=0)  # Reshape for batch (1, max_len, n_mfcc)

# %%
pred = model.predict(mfcc_seq)  # For Keras/TensorFlow models
predicted_class = np.argmax(pred)
predicted_emotion = le.classes_[predicted_class]
print("Predicted emotion:", predicted_emotion)
# Out:
# 1/1 [==============================] - 1s 1s/step
# Predicted emotion: surprised

# %%
# Example for a deep learning pipeline using MFCCs
test_file = '/Users/dushyantyadav/Downloads/Crema/1001_IEO_DIS_LO.wav'
mfcc_seq = extract_mfcc_sequence(test_file, max_len=200)  # Use your pipeline's function
mfcc_seq = np.expand_dims(mfcc_seq, axis=0)  # Reshape for batch (1, max_len, n_mfcc)

# %%
pred = model.predict(mfcc_seq)  # For Keras/TensorFlow models
predicted_class = np.argmax(pred)
predicted_emotion = le.classes_[predicted_class]
print("Predicted emotion:", predicted_emotion)
# Out:
# 1/1 [==============================] - 0s 50ms/step
# Predicted emotion: happy

# %%
# Example for a deep learning pipeline using MFCCs
test_file = '/Users/dushyantyadav/Downloads/Crema/1001_IOM_HAP_XX.wav'
mfcc_seq = extract_mfcc_sequence(test_file, max_len=200)  # Use your pipeline's function
mfcc_seq = np.expand_dims(mfcc_seq, axis=0)  # Reshape for batch (1, max_len, n_mfcc)

# %%
pred = model.predict(mfcc_seq)  # For Keras/TensorFlow models
predicted_class = np.argmax(pred)
predicted_emotion = le.classes_[predicted_class]
print("Predicted emotion:", predicted_emotion)
# Out:
# 1/1 [==============================] - 0s 151ms/step
# Predicted emotion: surprised

# %%
test_file = '/Users/dushyantyadav/Downloads/Crema/1083_IEO_ANG_MD.wav'
mfcc_seq = extract_mfcc_sequence(test_file, max_len=200)  # Use your pipeline's function
mfcc_seq = np.expand_dims(mfcc_seq, axis=0)  # Reshape for batch (1, max_len, n_mfcc)

# %%
pred = model.predict(mfcc_seq)  # For Keras/TensorFlow models
predicted_class = np.argmax(pred)
predicted_emotion = le.classes_[predicted_class]
print("Predicted emotion:", predicted_emotion)
# Out:
# 1/1 [==============================] - 0s 41ms/step
# Predicted emotion: surprised
